# %% [markdown]
# # __Masixole Boya__
# ### __Data Analytics Engineer__ Technical Assessment

# %% [markdown]
# ***
# # __0. Imports__
# ***
#
#
# ##### I have imported several libraries to support various functionalities in the code:
#
# - `os`: This library provides a way to interact with the operating system, and I use it to get the current working directory.
#
# - `json`: It allows me to work with JSON data, and I use it to read and manipulate JSON files.
#
#
# - `sqlalchemy.create_engine`: This function is from the SQLAlchemy library and is used to create a connection engine to interact with the SQL Server database.
#
# - `sqlalchemy.text`: This function is used to represent SQL expressions as Python string objects.
#
# - `pyodbc`: It is a Python module that makes accessing ODBC (Open Database Connectivity) databases simple.
#
# ## 0.1 Current Working Directory
#
# ##### I have set the current working directory using the `os.getcwd()` function to easily locate and read files in the file system.

# %%
import os
import json
import pandas as pd
from sqlalchemy import create_engine
from sqlalchemy import text
import pyodbc

# %% [markdown]
# ## __0.1 Current Working Directory__

# %%
current_path = os.getcwd()
current_path
# Out:
# 'c:\\Users\\STAFF\\Desktop\\Git_Repos\\Data_Engineering'

# %% [markdown]
# ***
# # __Question 1__: Automation - Export JSON Data and Import to SQL
#
# ***
#
#
# ##### I start by reading the content of the 'data.json' file using the `json.load` method. The data is then stored in the variable `json_data`.

# %% [markdown]
# ## __1.1 Reading the json file__

# %%
with open(current_path+'/data.json', 'r', encoding='utf-8') as file:
    json_data = json.load(file)

json_data
# Out:
# [{'name': 'Breanna Huffman',
#   'phone': '(764) 234-7824',
#   'email': 'lorem.sit@icloud.edu',
#   'address': 'P.O. Box 324, 5906 In Rd.',
#   'postalZip': '24-65',
#   'region': 'Guerrero',
#   'country': 'Philippines',
#   'list': 11,
#   'numberrange': 8,
#   'currency': '$77.26',
#   'alphanumeric': 'FYI84OMP4HD'},
#  {'name': 'Nomlanga David',
#   'phone': '(831) 152-6402',
#   'email': 'vel.venenatis.vel@yahoo.com',
#   'address': '5181 Egestas Ave',
#   'postalZip': '31218',
#   'region': 'Nuevo León',
#   'country': 'China',
#   'list': 3,
#   'numberrange': 1,
#   'currency': '$47.55',
#   'alphanumeric': 'BYQ14QWE9PI'},
#  {'name': 'Samuel Fulton',
#   'phone': '(236) 478-3395',
#   'email': 'ridiculus.mus.proin@outlook.couk',
#   'address': 'Ap #664-2516 Magna. Av.',
#   'postalZip': '745807',
#   'region': 'Mexico City',
#   'country': 'Turkey',
#   'list': 5,
#   'numberrange': 4,
#   'currency': '$89.28',
#   'alphanumeric': 'UFF24BGU1VD'},
#  {'name': 'Kennan Macias',
#   'phone': '1-987-725-3445',
#   'email': 'scelerisque.dui@yahoo.com',
#   'address': '1010 Semper Rd.',
#   'postalZip': '8626',
#   'region': 'West Region',
#   'country': 'Poland',
#   'list': 3,
#   'numberrange': 2,
#   'currency': '$3.02',
#   'alphanumeric': 'EAJ78GOI7CG'},
#  {'name': 'Levi Fulton',
#   'phone': '1-129-574-2583',
#   'email': 'nisl.arcu@protonmail.org',
#   'address': '997-9819 Primis Street',
#   'postalZip': '100048',
#   'region': 'Tasmania',
#   'country': 'Peru',
#   'list': 1,
#   'numberrange': 6,
#   'currency': '$7.82',
#   'alphanumeric': 'LWK55HMS8VM'},
#  {'name': 'Alisa Stevenson',
#   'phone': '(540) 745-6641',
#   'email': 'fames.ac@hotmail.net',
#   'address': '349-5526 Neque Road',
#   'postalZip': '122808',
#   'region': 'Östergötlands län',
#   'country': 'Vietnam',
#   'list': 19,
#   'numberrange': 5,
#   'currency': '$85.79',
#   'alphanumeric': 'JWB16BDR6PM'},
#  {'name': 'Mariko Dejesus',
#   'phone': '(352) 445-7721',
#   'email': 'amet@icloud.net',
#   'address': 'Ap #737-8976 In Av.',
#   'postalZip': '6556',
#   'region': 'Xīnán',
#   'country': 'Peru',
#   'list': 11,
#   'numberrange': 6,
#   'currency': '$28.53',
#   'alphanumeric': 'BZT86TTF2PY'},
#  {'name': 'Dora Mcleod',
#   'phone': '1-758-504-9383',
#   'email': 'quisque.imperdiet@hotmail.couk',
#   'address': 'Ap #638-589 Orci. Av.',
#   'postalZip': '18418',
#   'region': 'Xīnán',
#   'country': 'Netherlands',
#   'list': 9,
#   'numberrange': 4,
#   'currency': '$44.57',
#   'alphanumeric': 'FYD12YCU3FA'},
#  {'name': 'Wesley Hancock',
#   'phone': '(273) 863-8639',
#   'email': 'tincidunt@aol.net',
#   'address': '565-6579 Diam Road',
#   'postalZip': '52609-10882',
#   'region': 'Møre og Romsdal',
#   'country': 'Brazil',
#   'list': 5,
#   'numberrange': 1,
#   'currency': '$26.54',
#   'alphanumeric': 'RNX73ZLF6CB'},
#  {'name': 'Lance Blake',
#   'phone': '1-420-558-7471',
#   'email': 'orci.luctus@yahoo.net',
#   'address': '8689 Pharetra Street',
#   'postalZip': '648354',
#   'region': 'Quindío',
#   'country': 'India',
#   'list': 5,
#   'numberrange': 7,
#   'currency': '$22.83',
#   'alphanumeric': 'KUO42SIK4SK'},
#  {'name': 'Philip Hutchinson',
#   'phone': '(368) 388-7616',
#   'email': 'ornare.placerat@hotmail.couk',
#   'address': '7139 Sed, St.',
#   'postalZip': '285202',
#   'region': 'Hidalgo',
#   'country': 'Vietnam',
#   'list': 15,
#   'numberrange': 6,
#   'currency': '$28.04',
#   'alphanumeric': 'HVS75SQX2RJ'},
#  {'name': 'Danielle Chang',
#   'phone': '(478) 592-1870',
#   'email': 'in.ornare.sagittis@outlook.net',
#   'address': 'Ap #779-1673 Elementum Rd.',
#   'postalZip': '08802',
#   'region': 'Dadra and Nagar Haveli',
#   'country': 'France',
#   'list': 15,
#   'numberrange': 3,
#   'currency': '$74.54',
#   'alphanumeric': 'AMA13QUU3HO'},
#  {'name': 'Audrey Barrett',
#   'phone': '(858) 527-3123',
#   'email': 'tincidunt@icloud.ca',
#   'address': 'Ap #879-5960 Cras St.',
#   'postalZip': '65894',
#   'region': 'Antalya',
#   'country': 'Sweden',
#   'list': 11,
#   'numberrange': 4,
#   'currency': '$78.15',
#   'alphanumeric': 'RNS72RHH1IX'},
#  {'name': 'Brandon Macias',
#   'phone': '(148) 718-2681',
#   'email': 'nunc.risus@aol.couk',
#   'address': 'Ap #838-9645 Non St.',
#   'postalZip': '35V 8S5',
#   'region': 'Jönköpings län',
#   'country': 'Poland',
#   'list': 7,
#   'numberrange': 5,
#   'currency': '$4.77',
#   'alphanumeric': 'LAE45VIU0JA'},
#  {'name': 'Ivy Mcclure',
#   'phone': '1-464-168-6111',
#   'email': 'volutpat@yahoo.edu',
#   'address': '5502 Enim. Av.',
#   'postalZip': '305315',
#   'region': 'Munster',
#   'country': 'Costa Rica',
#   'list': 7,
#   'numberrange': 6,
#   'currency': '$34.28',
#   'alphanumeric': 'FBD96SLG1RJ'},
#  {'name': 'Talon Moody',
#   'phone': '(317) 332-6960',
#   'email': 'vestibulum@protonmail.com',
#   'address': 'P.O. Box 984, 4625 Ligula. St.',
#   'postalZip': '4434-7084',
#   'region': 'Marche',
#   'country': 'Italy',
#   'list': 7,
#   'numberrange': 7,
#   'currency': '$64.03',
#   'alphanumeric': 'WGM35GCH6KJ'},
#  {'name': 'Carissa Mejia',
#   'phone': '1-821-453-1384',
#   'email': 'lobortis@yahoo.net',
#   'address': 'P.O. Box 654, 9674 Dignissim Avenue',
#   'postalZip': '68709',
#   'region': 'Balochistan',
#   'country': 'South Korea',
#   'list': 15,
#   'numberrange': 5,
#   'currency': '$41.92',
#   'alphanumeric': 'WCC47KNR7LC'},
#  {'name': 'Irma Dean',
#   'phone': '1-744-557-4187',
#   'email': 'non.sollicitudin@yahoo.couk',
#   'address': '7769 Id, Road',
#   'postalZip': '884958',
#   'region': 'Tasmania',
#   'country': 'Ukraine',
#   'list': 9,
#   'numberrange': '0',
#   'currency': '$87.10',
#   'alphanumeric': 'PRN83XLJ5XX'},
#  {'name': 'Barrett Welch',
#   'phone': '(862) 602-7445',
#   'email': 'rutrum@outlook.net',
#   'address': '703-7878 Purus. St.',
#   'postalZip': '59337',
#   'region': 'Victoria',
#   'country': 'Australia',
#   'list': 13,
#   'numberrange': 9,
#   'currency': '$42.64',
#   'alphanumeric': 'EDM23KWV3KL'},
#  {'name': 'Chase Wolf',
#   'phone': '1-955-209-7218',
#   'email': 'enim.curabitur.massa@yahoo.couk',
#   'address': 'P.O. Box 865, 825 At, St.',
#   'postalZip': '3618',
#   'region': 'Sverdlovsk Oblast',
#   'country': 'Poland',
#   'list': 5,
#   'numberrange': 8,
#   'currency': '$17.85',
#   'alphanumeric': 'UHA04LLW2KH'},
#  {'name': 'Patrick Graham',
#   'phone': '1-301-558-0951',
#   'email': 'et.ultrices.posuere@hotmail.org',
#   'address': '438 Adipiscing St.',
#   'postalZip': '619272',
#   'region': 'Overijssel',
#   'country': 'Costa Rica',
#   'list': 17,
#   'numberrange': 1,
#   'currency': '$90.66',
#   'alphanumeric': 'EKB41YVC5VD'},
#  {'name': 'Odysseus Burt',
#   'phone': '(890) 246-3866',
#   'email': 'non.justo@protonmail.org',
#   'address': '435-8601 Egestas. Road',
#   'postalZip': '644488',
#   'region': 'Cantabria',
#   'country': 'Austria',
#   'list': 17,
#   'numberrange': 5,
#   'currency': '$33.37',
#   'alphanumeric': 'JGM03MMM8NM'},
#  {'name': 'Melyssa Kennedy',
#   'phone': '1-701-494-8154',
#   'email': 'felis.eget@protonmail.net',
#   'address': 'Ap #628-3933 Blandit Street',
#   'postalZip': '737861',
#   'region': 'Sverdlovsk Oblast',
#   'country': 'Ukraine',
#   'list': 5,
#   'numberrange': 8,
#   'currency': '$48.50',
#   'alphanumeric': 'WWX88NNC7FK'},
#  {'name': 'Tana Barron',
#   'phone': '1-918-547-2386',
#   'email': 'a.scelerisque@hotmail.couk',
#   'address': 'P.O. Box 938, 9601 Purus Street',
#   'postalZip': '517784',
#   'region': 'Oost-Vlaanderen',
#   'country': 'China',
#   'list': 7,
#   'numberrange': 5,
#   'currency': '$63.96',
#   'alphanumeric': 'YHO98IMY6XV'},
#  {'name': 'Idola Brock',
#   'phone': '1-897-161-2897',
#   'email': 'malesuada.vel@icloud.ca',
#   'address': 'P.O. Box 332, 9794 Aliquam Ave',
#   'postalZip': '22613',
#   'region': 'Guanacaste',
#   'country': 'Austria',
#   'list': 15,
#   'numberrange': 3,
#   'currency': '$40.20',
#   'alphanumeric': 'DXJ68NBE6YX'},
#  {'name': 'Tamara Matthews',
#   'phone': '1-794-725-3104',
#   'email': 'curabitur@aol.ca',
#   'address': '734-3681 Blandit Av.',
#   'postalZip': '6223',
#   'region': 'East Region',
#   'country': 'Colombia',
#   'list': 9,
#   'numberrange': 6,
#   'currency': '$35.96',
#   'alphanumeric': 'LUD34PUT3ID'},
#  {'name': 'Rhea Mays',
#   'phone': '1-357-289-6598',
#   'email': 'risus.donec.nibh@outlook.couk',
#   'address': 'Ap #342-1058 Convallis St.',
#   'postalZip': '584716',
#   'region': 'Luik',
#   'country': 'Belgium',
#   'list': 13,
#   'numberrange': 7,
#   'currency': '$29.69',
#   'alphanumeric': 'NLQ83WKH3ST'},
#  {'name': 'Kyra Hahn',
#   'phone': '1-541-567-2516',
#   'email': 'turpis.non@aol.edu',
#   'address': 'Ap #286-9996 Nam St.',
#   'postalZip': '16677',
#   'region': 'Vienna',
#   'country': 'Philippines',
#   'list': 15,
#   'numberrange': 4,
#   'currency': '$20.22',
#   'alphanumeric': 'SLB94VWG2OV'},
#  {'name': 'Kermit Vinson',
#   'phone': '(654) 458-2131',
#   'email': 'proin.ultrices@hotmail.edu',
#   'address': 'P.O. Box 217, 2853 Hendrerit St.',
#   'postalZip': '89264',
#   'region': 'Xīběi',
#   'country': 'Mexico',
#   'list': 9,
#   'numberrange': 4,
#   'currency': '$66.69',
#   'alphanumeric': 'PIK61YFE7GN'},
#  {'name': 'Caesar Witt',
#   'phone': '(344) 281-5557',
#   'email': 'montes.nascetur@google.edu',
#   'address': 'Ap #658-1990 Dolor Av.',
#   'postalZip': '43383',
#   'region': 'West Region',
#   'country': 'Ireland',
#   'list': 15,
#   'numberrange': 2,
#   'currency': '$62.22',
#   'alphanumeric': 'VXA46FIS1CC'},
#  {'name': 'Brody Bernard',
#   'phone': '(362) 883-6711',
#   'email': 'primis@google.edu',
#   'address': '797-6986 Senectus Street',
#   'postalZip': '753922',
#   'region': 'Lào Cai',
#   'country': 'Chile',
#   'list': 1,
#   'numberrange': 9,
#   'currency': '$94.44',
#   'alphanumeric': 'WYT88OYZ6EK'},
#  {'name': 'Emmanuel Mcguire',
#   'phone': '(533) 682-3539',
#   'email': 'felis.purus@hotmail.edu',
#   'address': 'Ap #435-1332 Lacus. Road',
#   'postalZip': '79916',
#   'region': 'FATA',
#   'country': 'Canada',
#   'list': 9,
#   'numberrange': 8,
#   'currency': '$11.70',
#   'alphanumeric': 'MQI51CFH6OG'},
#  {'name': 'Xenos Floyd',
#   'phone': '(189) 914-8457',
#   'email': 'dui.fusce@protonmail.net',
#   'address': '454-177 Interdum Avenue',
#   'postalZip': '266981',
#   'region': 'Overijssel',
#   'country': 'Costa Rica',
#   'list': 19,
#   'numberrange': 1,
#   'currency': '$34.10',
#   'alphanumeric': 'RCT36BTO8OJ'},
#  {'name': 'Signe Brennan',
#   'phone': '1-371-788-9188',
#   'email': 'sed.diam@outlook.net',
#   'address': '438-5987 Nulla St.',
#   'postalZip': '5593 NM',
#   'region': 'Burgenland',
#   'country': 'Peru',
#   'list': 7,
#   'numberrange': 4,
#   'currency': '$70.47',
#   'alphanumeric': 'VIY36EDM6ZH'},
#  {'name': 'Daquan Curry',
#   'phone': '(641) 946-8485',
#   'email': 'mattis.semper@yahoo.net',
#   'address': 'Ap #550-7873 Dui. Ave',
#   'postalZip': '7647',
#   'region': 'Balochistan',
#   'country': 'Pakistan',
#   'list': 3,
#   'numberrange': 2,
#   'currency': '$38.26',
#   'alphanumeric': 'TSE71CRL5UW'},
#  {'name': 'Maryam Glass',
#   'phone': '1-723-544-7667',
#   'email': 'elit.dictum@yahoo.net',
#   'address': '795-3248 Donec Rd.',
#   'postalZip': '26264',
#   'region': 'National Capital Region',
#   'country': 'United Kingdom',
#   'list': 15,
#   'numberrange': 2,
#   'currency': '$92.68',
#   'alphanumeric': 'DQE27WPN1EM'},
#  {'name': 'Austin Williamson',
#   'phone': '1-165-488-0646',
#   'email': 'fermentum.convallis@aol.net',
#   'address': '831-9943 Amet St.',
#   'postalZip': '8519',
#   'region': 'Lai Châu',
#   'country': 'China',
#   'list': 9,
#   'numberrange': 4,
#   'currency': '$91.59',
#   'alphanumeric': 'BQU28OWI4DR'},
#  {'name': 'Hashim Hendrix',
#   'phone': '(450) 644-2518',
#   'email': 'vitae@yahoo.net',
#   'address': 'Ap #722-1038 Sollicitudin Av.',
#   'postalZip': '85377',
#   'region': 'Noord Brabant',
#   'country': 'South Korea',
#   'list': 13,
#   'numberrange': 6,
#   'currency': '$0.42',
#   'alphanumeric': 'FKJ58ZOU5EU'},
#  {'name': 'Jeanette Moody',
#   'phone': '1-336-662-4588',
#   'email': 'adipiscing.mauris.molestie@yahoo.com',
#   'address': '447-8614 Gravida Rd.',
#   'postalZip': '56-72',
#   'region': 'Carinthia',
#   'country': 'Russian Federation',
#   'list': 19,
#   'numberrange': 4,
#   'currency': '$8.30',
#   'alphanumeric': 'POE23XEH2YV'},
#  {'name': 'Georgia Atkins',
#   'phone': '(747) 755-5850',
#   'email': 'fringilla.porttitor@hotmail.org',
#   'address': 'Ap #542-3713 Libero. Ave',
#   'postalZip': '407127',
#   'region': 'KwaZulu-Natal',
#   'country': 'Costa Rica',
#   'list': 17,
#   'numberrange': '0',
#   'currency': '$33.62',
#   'alphanumeric': 'LGR81TXD3WL'},
#  {'name': 'Moses Burch',
#   'phone': '(128) 847-4292',
#   'email': 'nulla.integer@hotmail.couk',
#   'address': 'P.O. Box 719, 9609 Tristique Street',
#   'postalZip': '649462',
#   'region': 'Drenthe',
#   'country': 'Vietnam',
#   'list': 9,
#   'numberrange': 5,
#   'currency': '$5.28',
#   'alphanumeric': 'RLG22YJJ1UR'},
#  {'name': 'Howard Pitts',
#   'phone': '(527) 414-1813',
#   'email': 'ac.ipsum@outlook.ca',
#   'address': '1120 Tortor. Road',
#   'postalZip': '41427',
#   'region': 'Cusco',
#   'country': 'Indonesia',
#   'list': 5,
#   'numberrange': 3,
#   'currency': '$10.15',
#   'alphanumeric': 'XXV95HRC8IK'},
#  {'name': 'Elton Bennett',
#   'phone': '(453) 452-7545',
#   'email': 'nec.mauris@icloud.ca',
#   'address': 'Ap #865-4917 Vitae, Av.',
#   'postalZip': '02144',
#   'region': 'Kemerovo Oblast',
#   'country': 'Mexico',
#   'list': 11,
#   'numberrange': 5,
#   'currency': '$91.75',
#   'alphanumeric': 'ZBG30KBJ7CJ'},
#  {'name': 'Ria Gates',
#   'phone': '1-348-967-7869',
#   'email': 'nunc.sed@google.edu',
#   'address': '761-6911 Semper. Road',
#   'postalZip': '71500',
#   'region': "O'Higgins",
#   'country': 'Brazil',
#   'list': 7,
#   'numberrange': 3,
#   'currency': '$37.89',
#   'alphanumeric': 'FWW34OUX5SJ'},
#  {'name': 'Emma Griffin',
#   'phone': '1-750-166-3083',
#   'email': 'dui.cum.sociis@protonmail.ca',
#   'address': 'Ap #359-9768 Fringilla Ave',
#   'postalZip': '823989',
#   'region': 'Balochistan',
#   'country': 'Ukraine',
#   'list': 9,
#   'numberrange': 6,
#   'currency': '$47.72',
#   'alphanumeric': 'STO93ONB0LJ'},
#  {'name': 'Daphne Serrano',
#   'phone': '1-534-686-6423',
#   'email': 'tristique@outlook.edu',
#   'address': '925-5251 Amet Road',
#   'postalZip': 'QC6R 6YF',
#   'region': 'Haryana',
#   'country': 'Ireland',
#   'list': 15,
#   'numberrange': 9,
#   'currency': '$52.51',
#   'alphanumeric': 'CWP26CVP9WY'},
#  {'name': 'Harding Frye',
#   'phone': '(677) 667-7480',
#   'email': 'sagittis.semper.nam@icloud.edu',
#   'address': '9052 Aliquet St.',
#   'postalZip': '16175',
#   'region': 'Mersin',
#   'country': 'Austria',
#   'list': 17,
#   'numberrange': 3,
#   'currency': '$69.78',
#   'alphanumeric': 'RTD10CKJ5IK'},
#  {'name': 'Carlos Tillman',
#   'phone': '(843) 235-5883',
#   'email': 'metus.in@yahoo.net',
#   'address': '681-1872 Penatibus Av.',
#   'postalZip': '717527',
#   'region': 'North Kalimantan',
#   'country': 'Netherlands',
#   'list': 19,
#   'numberrange': 1,
#   'currency': '$21.10',
#   'alphanumeric': 'PWC45AOP1VV'},
#  {'name': 'Lamar Spears',
#   'phone': '(681) 132-3427',
#   'email': 'non.egestas.a@protonmail.com',
#   'address': 'Ap #996-1964 Vestibulum St.',
#   'postalZip': '86599',
#   'region': 'Podlaskie',
#   'country': 'Ukraine',
#   'list': 5,
#   'numberrange': 9,
#   'currency': '$76.25',
#   'alphanumeric': 'XVW33EVN4DP'},
#  {'name': 'Elton Bird',
#   'phone': '1-766-173-2304',
#   'email': 'diam.pellentesque.habitant@protonmail.couk',
#   'address': 'Ap #249-1219 Ridiculus Rd.',
#   'postalZip': '3267',
#   'region': 'Östergötlands län',
#   'country': 'Peru',
#   'list': 1,
#   'numberrange': 7,
#   'currency': '$17.63',
#   'alphanumeric': 'GXM68LCU2YX'},
#  {'name': 'Shana Hensley',
#   'phone': '1-446-398-7348',
#   'email': 'ornare.lectus.ante@icloud.ca',
#   'address': 'Ap #610-3120 Orci. St.',
#   'postalZip': '825339',
#   'region': 'Gilgit Baltistan',
#   'country': 'Peru',
#   'list': 9,
#   'numberrange': 2,
#   'currency': '$68.89',
#   'alphanumeric': 'ODR76WXG4LO'},
#  {'name': 'Ursula Everett',
#   'phone': '1-457-796-6668',
#   'email': 'ac.orci@outlook.net',
#   'address': '797-1082 Eu Road',
#   'postalZip': '8119-8397',
#   'region': 'Stockholms län',
#   'country': 'France',
#   'list': 19,
#   'numberrange': 2,
#   'currency': '$98.93',
#   'alphanumeric': 'LFE17ZEJ8ZH'},
#  {'name': 'Nicholas Rodriguez',
#   'phone': '1-558-721-2956',
#   'email': 'et@outlook.com',
#   'address': 'Ap #763-7884 Amet, Rd.',
#   'postalZip': '4606',
#   'region': 'La Rioja',
#   'country': 'Costa Rica',
#   'list': 1,
#   'numberrange': 7,
#   'currency': '$31.75',
#   'alphanumeric': 'IRT68VIV1FW'},
#  {'name': 'Kellie Carlson',
#   'phone': '(426) 666-4841',
#   'email': 'vel.quam@yahoo.com',
#   'address': 'Ap #591-8280 Tristique Street',
#   'postalZip': '3140-6610',
#   'region': 'Northern Territory',
#   'country': 'Singapore',
#   'list': 9,
#   'numberrange': 9,
#   'currency': '$65.08',
#   'alphanumeric': 'ASD92NLH3MQ'},
#  {'name': 'Palmer Williamson',
#   'phone': '1-908-165-6355',
#   'email': 'metus.facilisis@outlook.ca',
#   'address': '2961 Enim. St.',
#   'postalZip': '26-667',
#   'region': 'Limón',
#   'country': 'Netherlands',
#   'list': 19,
#   'numberrange': 1,
#   'currency': '$99.67',
#   'alphanumeric': 'CFX32XJI7DP'},
#  {'name': 'Gemma Kline',
#   'phone': '1-536-355-0388',
#   'email': 'nec.tempus.mauris@icloud.net',
#   'address': '330-9756 Non, Avenue',
#   'postalZip': '15882-357',
#   'region': 'Västra Götalands län',
#   'country': 'Ukraine',
#   'list': 5,
#   'numberrange': 6,
#   'currency': '$27.31',
#   'alphanumeric': 'OVO13GGN5SW'},
#  {'name': 'Jana Garrison',
#   'phone': '(603) 971-9433',
#   'email': 'neque.venenatis.lacus@icloud.ca',
#   'address': 'P.O. Box 594, 4395 In St.',
#   'postalZip': '552825',
#   'region': 'Cheshire',
#   'country': 'United Kingdom',
#   'list': 17,
#   'numberrange': 10,
#   'currency': '$42.78',
#   'alphanumeric': 'SOO17TQW9OI'},
#  {'name': 'Sean Huff',
#   'phone': '(111) 227-3145',
#   'email': 'porta.elit.a@google.net',
#   'address': 'Ap #753-2795 A Avenue',
#   'postalZip': '9413',
#   'region': 'Zhōngnán',
#   'country': 'Brazil',
#   'list': 11,
#   'numberrange': 7,
#   'currency': '$39.14',
#   'alphanumeric': 'NJX43JCR4CP'},
#  {'name': 'Moses Serrano',
#   'phone': '(658) 331-7285',
#   'email': 'nec.metus.facilisis@protonmail.com',
#   'address': 'P.O. Box 768, 7234 Ullamcorper, Rd.',
#   'postalZip': '25110',
#   'region': 'Manitoba',
#   'country': 'Sweden',
#   'list': 15,
#   'numberrange': 7,
#   'currency': '$39.31',
#   'alphanumeric': 'UIQ11QFF3QF'},
#  {'name': 'Brennan Castaneda',
#   'phone': '1-732-832-8521',
#   'email': 'justo@icloud.net',
#   'address': 'Ap #588-5366 Nunc, Road',
#   'postalZip': '63046',
#   'region': 'Saskatchewan',
#   'country': 'Poland',
#   'list': 9,
#   'numberrange': 10,
#   'currency': '$48.24',
#   'alphanumeric': 'YHI24BSB0HH'},
#  {'name': 'Justina Pittman',
#   'phone': '1-674-852-3311',
#   'email': 'egestas@google.com',
#   'address': '6304 Eu Street',
#   'postalZip': '734937',
#   'region': 'Liguria',
#   'country': 'Austria',
#   'list': 17,
#   'numberrange': 9,
#   'currency': '$1.29',
#   'alphanumeric': 'MQZ38WXG8UQ'},
#  {'name': 'Ronan Sears',
#   'phone': '1-543-718-1343',
#   'email': 'adipiscing.non@yahoo.com',
#   'address': 'P.O. Box 231, 5770 Ac Street',
#   'postalZip': '473507',
#   'region': 'Bayern',
#   'country': 'Nigeria',
#   'list': 7,
#   'numberrange': 4,
#   'currency': '$78.08',
#   'alphanumeric': 'MOV44UNG0XC'},
#  {'name': 'Sierra Weeks',
#   'phone': '(741) 517-3487',
#   'email': 'et.pede@protonmail.net',
#   'address': '392-9823 Magnis St.',
#   'postalZip': '8516',
#   'region': 'Upper Austria',
#   'country': 'Colombia',
#   'list': 1,
#   'numberrange': 1,
#   'currency': '$62.24',
#   'alphanumeric': 'MOB55XLT8IE'},
#  {'name': 'Graham Knox',
#   'phone': '(616) 503-3077',
#   'email': 'feugiat.metus@protonmail.edu',
#   'address': '973-9452 Neque. St.',
#   'postalZip': '23-53',
#   'region': 'Eastern Cape',
#   'country': 'Philippines',
#   'list': 15,
#   'numberrange': 8,
#   'currency': '$99.12',
#   'alphanumeric': 'UFP57TQA2CH'},
#  {'name': 'Rachel Serrano',
#   'phone': '1-544-421-7235',
#   'email': 'id@protonmail.org',
#   'address': '840 Dolor, Street',
#   'postalZip': '6491',
#   'region': 'Vlaams-Brabant',
#   'country': 'Austria',
#   'list': 13,
#   'numberrange': 3,
#   'currency': '$86.71',
#   'alphanumeric': 'ZYR24BDB3PW'},
#  {'name': 'Shoshana Farrell',
#   'phone': '1-258-427-5761',
#   'email': 'diam.at.pretium@yahoo.couk',
#   'address': 'Ap #576-7079 Consectetuer Rd.',
#   'postalZip': '16526',
#   'region': 'Eastern Cape',
#   'country': 'Poland',
#   'list': 17,
#   'numberrange': 3,
#   'currency': '$37.20',
#   'alphanumeric': 'OPY01UJY0KV'},
#  {'name': 'Isadora Atkinson',
#   'phone': '1-590-433-9282',
#   'email': 'sociosqu@google.com',
#   'address': '359-9914 Proin Rd.',
#   'postalZip': 'H3P 5L3',
#   'region': 'Noord Holland',
#   'country': 'United Kingdom',
#   'list': 15,
#   'numberrange': 3,
#   'currency': '$94.61',
#   'alphanumeric': 'XEQ29USX7CM'},
#  {'name': 'MacKensie Stout',
#   'phone': '(231) 150-8122',
#   'email': 'phasellus.vitae.mauris@hotmail.com',
#   'address': 'P.O. Box 603, 289 Id Ave',
#   'postalZip': '585365',
#   'region': 'Nagaland',
#   'country': 'Italy',
#   'list': 13,
#   'numberrange': 6,
#   'currency': '$52.03',
#   'alphanumeric': 'RKN12QXB8VA'},
#  {'name': 'Jared Woodard',
#   'phone': '1-745-728-4615',
#   'email': 'dolor.quam.elementum@outlook.net',
#   'address': '614-1881 Aliquet Street',
#   'postalZip': '3807',
#   'region': 'Free State',
#   'country': 'Germany',
#   'list': 5,
#   'numberrange': 3,
#   'currency': '$11.17',
#   'alphanumeric': 'RCU21VWU5YE'},
#  {'name': 'Keelie Steele',
#   'phone': '1-693-604-4372',
#   'email': 'praesent.eu.nulla@google.couk',
#   'address': 'Ap #764-9830 Orci, Road',
#   'postalZip': '93336',
#   'region': 'Mississippi',
#   'country': 'Mexico',
#   'list': 11,
#   'numberrange': 8,
#   'currency': '$88.77',
#   'alphanumeric': 'TPO52UOT8LU'},
#  {'name': 'Lani Chase',
#   'phone': '(842) 381-3827',
#   'email': 'erat.volutpat@hotmail.org',
#   'address': 'P.O. Box 405, 181 Tincidunt, Rd.',
#   'postalZip': '26584',
#   'region': 'San José',
#   'country': 'South Korea',
#   'list': 7,
#   'numberrange': 4,
#   'currency': '$90.05',
#   'alphanumeric': 'GXO24NKP1YY'},
#  {'name': 'Ainsley Benton',
#   'phone': '(219) 139-5795',
#   'email': 'a@yahoo.org',
#   'address': '8412 Mollis Rd.',
#   'postalZip': '899471',
#   'region': 'Kirovohrad oblast',
#   'country': 'Norway',
#   'list': 17,
#   'numberrange': 9,
#   'currency': '$37.11',
#   'alphanumeric': 'AKH57RIH0QV'},
#  {'name': 'Jason Snider',
#   'phone': '1-671-212-3289',
#   'email': 'sem.semper.erat@hotmail.couk',
#   'address': '988-6830 Dictum Rd.',
#   'postalZip': '6261 UU',
#   'region': 'Calabria',
#   'country': 'South Korea',
#   'list': 13,
#   'numberrange': 5,
#   'currency': '$83.79',
#   'alphanumeric': 'REU60FKE9FN'},
#  {'name': 'Imogene Burke',
#   'phone': '(607) 458-6320',
#   'email': 'eu.ultrices@hotmail.com',
#   'address': '502-9513 Aliquet, St.',
#   'postalZip': '3415-4303',
#   'region': 'Sinaloa',
#   'country': 'Norway',
#   'list': 5,
#   'numberrange': '0',
#   'currency': '$36.68',
#   'alphanumeric': 'YNI10HOC3DJ'},
#  {'name': 'Sara Merritt',
#   'phone': '(754) 779-5336',
#   'email': 'elementum.purus@icloud.ca',
#   'address': 'Ap #222-7427 Donec St.',
#   'postalZip': '02373',
#   'region': 'North Island',
#   'country': 'Brazil',
#   'list': 7,
#   'numberrange': 8,
#   'currency': '$93.77',
#   'alphanumeric': 'PCF97PSU2NP'},
#  {'name': 'Troy Mosley',
#   'phone': '1-471-201-3257',
#   'email': 'diam.nunc@protonmail.org',
#   'address': 'P.O. Box 270, 8041 Nascetur Ave',
#   'postalZip': '552687',
#   'region': 'Quebec',
#   'country': 'Indonesia',
#   'list': 17,
#   'numberrange': 4,
#   'currency': '$70.33',
#   'alphanumeric': 'SGE47YDK3HQ'},
#  {'name': 'Colette Hunt',
#   'phone': '(576) 804-4738',
#   'email': 'enim.diam@google.edu',
#   'address': '529-330 Amet St.',
#   'postalZip': '334800',
#   'region': 'Odessa oblast',
#   'country': 'Mexico',
#   'list': 3,
#   'numberrange': 9,
#   'currency': '$15.16',
#   'alphanumeric': 'RCG27FYC3YB'},
#  {'name': 'Ignatius Ellis',
#   'phone': '(833) 128-1653',
#   'email': 'in.faucibus@outlook.net',
#   'address': 'P.O. Box 887, 5086 Integer St.',
#   'postalZip': 'G6T 6Y3',
#   'region': 'Madrid',
#   'country': 'Germany',
#   'list': 5,
#   'numberrange': '0',
#   'currency': '$30.42',
#   'alphanumeric': 'XHM89VOZ7NR'},
#  {'name': 'Kadeem Zimmerman',
#   'phone': '1-256-575-4133',
#   'email': 'ante@google.couk',
#   'address': 'P.O. Box 996, 8521 Semper, Rd.',
#   'postalZip': '275222',
#   'region': 'Junín',
#   'country': 'Chile',
#   'list': 9,
#   'numberrange': 4,
#   'currency': '$57.83',
#   'alphanumeric': 'UIU24NIL4UX'},
#  {'name': 'Nita Lee',
#   'phone': '(585) 382-3564',
#   'email': 'volutpat.ornare@outlook.com',
#   'address': 'Ap #566-5907 Ut Avenue',
#   'postalZip': '63365-52331',
#   'region': 'Liguria',
#   'country': 'Mexico',
#   'list': 17,
#   'numberrange': 4,
#   'currency': '$94.16',
#   'alphanumeric': 'EWL17QCB6JP'},
#  {'name': 'Norman Albert',
#   'phone': '(268) 647-7305',
#   'email': 'eget.laoreet.posuere@icloud.com',
#   'address': '1703 Blandit Av.',
#   'postalZip': '2728',
#   'region': 'Central Java',
#   'country': 'United Kingdom',
#   'list': 7,
#   'numberrange': 9,
#   'currency': '$12.84',
#   'alphanumeric': 'FCM52QEC4IK'},
#  {'name': 'Ralph Mayer',
#   'phone': '(145) 854-6385',
#   'email': 'risus@google.couk',
#   'address': 'Ap #397-1916 At Av.',
#   'postalZip': '33878',
#   'region': 'North Jeolla',
#   'country': 'Vietnam',
#   'list': 1,
#   'numberrange': 3,
#   'currency': '$50.75',
#   'alphanumeric': 'MOW24ASX5OE'},
#  {'name': 'Wade Hudson',
#   'phone': '(423) 267-1245',
#   'email': 'non@aol.edu',
#   'address': '6932 Faucibus Avenue',
#   'postalZip': '217366',
#   'region': 'Jeju',
#   'country': 'Belgium',
#   'list': 15,
#   'numberrange': 1,
#   'currency': '$81.47',
#   'alphanumeric': 'CDF48XDN8NL'},
#  {'name': 'Eliana Hoover',
#   'phone': '(854) 234-7111',
#   'email': 'aenean.massa@yahoo.org',
#   'address': '667-4587 Libero Rd.',
#   'postalZip': '3074-3580',
#   'region': 'Limburg',
#   'country': 'Australia',
#   'list': 19,
#   'numberrange': 1,
#   'currency': '$8.22',
#   'alphanumeric': 'DTS11VDB4BL'},
#  {'name': 'Macy Flores',
#   'phone': '(811) 373-6385',
#   'email': 'mauris@aol.net',
#   'address': '810-962 Ligula. St.',
#   'postalZip': '6316',
#   'region': 'Fife',
#   'country': 'Ireland',
#   'list': 7,
#   'numberrange': 6,
#   'currency': '$25.88',
#   'alphanumeric': 'QMC47NDK0AH'},
#  {'name': 'Karyn Livingston',
#   'phone': '1-407-645-2850',
#   'email': 'luctus.felis@yahoo.com',
#   'address': 'P.O. Box 387, 3508 Metus Rd.',
#   'postalZip': '3445',
#   'region': 'Northern Territory',
#   'country': 'India',
#   'list': 7,
#   'numberrange': 7,
#   'currency': '$84.74',
#   'alphanumeric': 'WTO01EJT1GX'},
#  {'name': 'Cameron Mcfarland',
#   'phone': '(677) 765-1388',
#   'email': 'tincidunt@hotmail.org',
#   'address': 'Ap #118-5344 Neque. Rd.',
#   'postalZip': '81913-83291',
#   'region': 'Zhōngnán',
#   'country': 'Austria',
#   'list': 5,
#   'numberrange': 4,
#   'currency': '$81.25',
#   'alphanumeric': 'OBI67UCY4PO'},
#  {'name': 'Zena Flynn',
#   'phone': '(454) 822-2156',
#   'email': 'tempus.scelerisque.lorem@aol.com',
#   'address': '777-3716 Elit Rd.',
#   'postalZip': '8364',
#   'region': 'Saarland',
#   'country': 'Brazil',
#   'list': 5,
#   'numberrange': 8,
#   'currency': '$30.41',
#   'alphanumeric': 'CBJ79JID5FV'},
#  {'name': 'Magee Williamson',
#   'phone': '1-993-113-5573',
#   'email': 'eget.massa@protonmail.edu',
#   'address': 'P.O. Box 457, 3892 Nostra, Rd.',
#   'postalZip': '9888',
#   'region': 'Leinster',
#   'country': 'Ukraine',
#   'list': 9,
#   'numberrange': 7,
#   'currency': '$45.87',
#   'alphanumeric': 'PJW24BWH4HF'},
#  {'name': 'Knox Bean',
#   'phone': '1-796-548-2620',
#   'email': 'iaculis.aliquet@yahoo.ca',
#   'address': '2520 Suspendisse Street',
#   'postalZip': '73231',
#   'region': 'North Island',
#   'country': 'United States',
#   'list': 15,
#   'numberrange': '0',
#   'currency': '$14.57',
#   'alphanumeric': 'QCT43WKU1OG'},
#  {'name': 'Rhoda Gibbs',
#   'phone': '1-157-464-1030',
#   'email': 'hendrerit.a.arcu@outlook.net',
#   'address': 'P.O. Box 168, 7425 Magna. St.',
#   'postalZip': '3269',
#   'region': 'Jeju',
#   'country': 'Ireland',
#   'list': 17,
#   'numberrange': 3,
#   'currency': '$75.39',
#   'alphanumeric': 'OQJ53WRJ2VD'},
#  {'name': 'Dahlia Roach',
#   'phone': '(822) 882-8340',
#   'email': 'dictum.eleifend@aol.net',
#   'address': 'P.O. Box 392, 9967 Risus Road',
#   'postalZip': '77242',
#   'region': 'Tasmania',
#   'country': 'Mexico',
#   'list': 15,
#   'numberrange': 3,
#   'currency': '$92.22',
#   'alphanumeric': 'KVA51RYS6DX'},
#  {'name': 'Juliet Keller',
#   'phone': '(712) 655-2527',
#   'email': 'tincidunt.nunc@hotmail.org',
#   'address': '975-3938 Tincidunt Rd.',
#   'postalZip': '21664',
#   'region': 'Paraná',
#   'country': 'Spain',
#   'list': 15,
#   'numberrange': '0',
#   'currency': '$91.25',
#   'alphanumeric': 'FDW12SDO3LL'},
#  {'name': 'Eleanor Davenport',
#   'phone': '1-567-554-3725',
#   'email': 'facilisis.eget@outlook.couk',
#   'address': 'Ap #531-5194 Felis. Road',
#   'postalZip': '28031',
#   'region': 'Western Australia',
#   'country': 'Singapore',
#   'list': 13,
#   'numberrange': 9,
#   'currency': '$64.01',
#   'alphanumeric': 'MOQ11GEN4HV'},
#  {'name': 'Jane Dickerson',
#   'phone': '1-983-308-5253',
#   'email': 'tincidunt@aol.net',
#   'address': '278-1122 Risus Avenue',
#   'postalZip': '8730',
#   'region': 'Styria',
#   'country': 'Nigeria',
#   'list': 19,
#   'numberrange': 7,
#   'currency': '$27.87',
#   'alphanumeric': 'JCH11FQC3MF'},
#  {'name': 'Tatum Pitts',
#   'phone': '1-609-365-3007',
#   'email': 'quis.massa@outlook.net',
#   'address': 'P.O. Box 193, 4431 Dolor St.',
#   'postalZip': '8216',
#   'region': 'Cajamarca',
#   'country': 'South Africa',
#   'list': 17,
#   'numberrange': 8,
#   'currency': '$34.79',
#   'alphanumeric': 'VKA63NJB6GQ'},
#  {'name': 'Christopher Weber',
#   'phone': '(192) 682-1857',
#   'email': 'nam.nulla@icloud.com',
#   'address': '219-5882 Iaculis Av.',
#   'postalZip': '682224',
#   'region': 'Bremen',
#   'country': 'Poland',
#   'list': 11,
#   'numberrange': 6,
#   'currency': '$46.08',
#   'alphanumeric': 'HGP27IPG8AG'},
#  {'name': 'Quinlan Howell',
#   'phone': '1-322-670-0802',
#   'email': 'in.condimentum@protonmail.edu',
#   'address': 'Ap #824-6551 Dui Rd.',
#   'postalZip': '80141',
#   'region': 'Santander',
#   'country': 'Ireland',
#   'list': 5,
#   'numberrange': 1,
#   'currency': '$89.08',
#   'alphanumeric': 'BOI35WXB6WN'},
#  {'name': 'Keaton Barry',
#   'phone': '(531) 125-2396',
#   'email': 'non.lorem@outlook.com',
#   'address': 'Ap #605-9106 Tincidunt. Avenue',
#   'postalZip': '7771',
#   'region': 'Australian Capital Territory',
#   'country': 'Nigeria',
#   'list': 1,
#   'numberrange': 7,
#   'currency': '$13.62',
#   'alphanumeric': 'FON59GRX5DE'},
#  {'name': 'Mara Marsh',
#   'phone': '1-595-336-0678',
#   'email': 'velit.aliquam@protonmail.edu',
#   'address': 'Ap #893-4647 Sit Av.',
#   'postalZip': '55-221',
#   'region': 'Antofagasta',
#   'country': 'Canada',
#   'list': 7,
#   'numberrange': 2,
#   'currency': '$6.84',
#   'alphanumeric': 'XXY74OMA2ZW'}]

# %% [markdown]
# ## __1.2 Connecting to SQL Server__
#
#
#
# ##### I establish a connection to the SQL Server using the `pyodbc` library. The connection details include the driver, server name (DESKTOP-S7VHLIE\\SQLEXPRESS), the database name (CustomerTransactions), and Windows Authentication (Trusted_Connection=yes). After establishing the connection, I create a cursor to execute SQL queries. The connection is committed, and the database to be used is set to 'CustomerTransactions'.

# %%
conn = pyodbc.connect(
    'Driver={SQL Server};'
    'Server=DESKTOP-S7VHLIE\\SQLEXPRESS;'
    'Database=CustomerTransactions;'
    'Trusted_Connection=yes;'
)

cursor = conn.cursor()

# %%
conn.commit()

# %%
cursor.execute('use CustomerTransactions')

# %% [markdown]
# ## __1.3 Preparing to create the SQL table__

# %%
columns_and_types = [(column, type(json_data[0][column]).__name__) 
                     for column in json_data[0]]
columns_and_types
# Out:
# [('name', 'str'),
#  ('phone', 'str'),
#  ('email', 'str'),
#  ('address', 'str'),
#  ('postalZip', 'str'),
#  ('region', 'str'),
#  ('country', 'str'),
#  ('list', 'int'),
#  ('numberrange', 'int'),
#  ('currency', 'str'),
#  ('alphanumeric', 'str')]

# %%
python_to_sql_type = {
    'str': 'NVARCHAR(MAX)',
    'int': 'INT',
    'float': 'FLOAT',
    'bool': 'BIT',
}

columns_and_types_mapped = [
    (column, python_to_sql_type[data_type.lower()]) 
    for column, data_type in columns_and_types
    ]

# %%
columns_and_types_mapped
# Out:
# [('name', 'NVARCHAR(MAX)'),
#  ('phone', 'NVARCHAR(MAX)'),
#  ('email', 'NVARCHAR(MAX)'),
#  ('address', 'NVARCHAR(MAX)'),
#  ('postalZip', 'NVARCHAR(MAX)'),
#  ('region', 'NVARCHAR(MAX)'),
#  ('country', 'NVARCHAR(MAX)'),
#  ('list', 'INT'),
#  ('numberrange', 'INT'),
#  ('currency', 'NVARCHAR(MAX)'),
#  ('alphanumeric', 'NVARCHAR(MAX)')]

# %% [markdown]
# ## __1.4 Creating the SQL table__
#
#
# ##### I prepare to create an SQL table based on the structure of the JSON data. I extract the column names and their corresponding Python data types from the first entry of the JSON data. Using a mapping dictionary (`python_to_sql_type`), I map Python data types to their equivalent SQL Server data types. The resulting list (`columns_and_types_mapped`) contains tuples with column names and their corresponding SQL data types.

# %%
create_table_sql = f'''
CREATE TABLE JSON_TABLE (
    {', '.join([f'{column} {data_type}' for column, data_type in columns_and_types_mapped])}
)
'''
cursor.execute(create_table_sql)

# %%
conn.commit()

# %% [markdown]
# ## __1.5 Importing JSON data into the SQL table__
#
#
# ##### For each record in the JSON data, I sanitize the data by replacing single quotes (`'`) with underscores (`_`) in string values. This step is essential to prevent SQL injection and ensure proper data insertion. I then construct an SQL INSERT statement based on the columns and types mapped earlier. The data values are inserted using placeholders (`?`), and the sanitized values from each record are executed using the cursor. This process ensures that the JSON data is safely and accurately inserted into the SQL table.

# %%
for record in json_data:
    sanitized_record = {key: value.replace("'", '_') if isinstance(value, str) else value for key, value in record.items()}

    insert_sql = f'''
    INSERT INTO JSON_TABLE ({', '.join(column for column, _ in columns_and_types_mapped)})
    VALUES ({', '.join(['?' for _ in columns_and_types_mapped])})
    '''
    cursor.execute(insert_sql, list(sanitized_record.values()))

# %%
conn.commit()

# %% [markdown]
# ##### I construct an SQL SELECT statement to retrieve the top 5 rows from the SQL table named `JSON_TABLE`. The cursor executes this query, and the result is fetched and printed row by row. This step allows me to verify the successful insertion of data into the SQL table and observe the content retrieved from the table.

# %%
select_sql = '''
SELECT TOP 5 *
FROM JSON_TABLE
'''

result = cursor.execute(select_sql).fetchall()

for row in result:
    print(row)
# Out:
# ('Breanna Huffman', '(764) 234-7824', 'lorem.sit@icloud.edu', 'P.O. Box 324, 5906 In Rd.', '24-65', 'Guerrero', 'Philippines', 11, 8, '$77.26', 'FYI84OMP4HD')
# ('Nomlanga David', '(831) 152-6402', 'vel.venenatis.vel@yahoo.com', '5181 Egestas Ave', '31218', 'Nuevo León', 'China', 3, 1, '$47.55', 'BYQ14QWE9PI')
# ('Samuel Fulton', '(236) 478-3395', 'ridiculus.mus.proin@outlook.couk', 'Ap #664-2516 Magna. Av.', '745807', 'Mexico City', 'Turkey', 5, 4, '$89.28', 'UFF24BGU1VD')
# ('Kennan Macias', '1-987-725-3445', 'scelerisque.dui@yahoo.com', '1010 Semper Rd.', '8626', 'West Region', 'Poland', 3, 2, '$3.02', 'EAJ78GOI7CG')
# ('Levi Fulton', '1-129-574-2583', 'nisl.arcu@protonmail.org', '997-9819 Primis Street', '100048', 'Tasmania', 'Peru', 1, 6, '$7.82', 'LWK55HMS8VM')

# %%
cursor.close()
conn.close()

# %% [markdown]
# ## __1.6 Deleting the JSON file__

# %%
json_file = current_path+ "/data.json"
try:
    os.remove(json_file)
    print("JSON file deleted successfully.")
except Exception as e:
    raise Exception(f"Error deleting JSON file: {str(e)}")
# Out:
# JSON file deleted successfully.
